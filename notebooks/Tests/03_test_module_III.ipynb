# %% [markdown]
# # **Aplicaciones Financieras de ML & AI**
# ## **Examen III:** *AI in Finance*
#
# #### Nombre: Julio César Avila Torreblanca
#
# - **Problema:**
#     * Genere un modelo que dato un texto, nos regrese como predicción un salario estimado o un rango salarial estimado (use al menos 3 variables).
#         - Use un modelo o variante de Bert.
#     * Base de datos: consiste en Empleos, Descripciones de los empleos y Rango salarial.
#
#
# - **Contenido del notebook**:
#     1. Librerías y parámetros
#     2. Lectura de datos
#     3. EDA
#     4. Procesamiento de datos
#     5. Modelado
#     6. Evaluación

# %% [markdown]
# # 1. Librerías y parámetros

# %%
# data manipulation
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin

# nn
from transformers import  AutoTokenizer
from sentence_transformers import SentenceTransformer
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, regularizers

# test
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# visualization
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Lectura de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/Academy/Diplomado_Finanazas&IA/01_Aplicaciones_Financieras_ML&AI/Tests/DataAnalyst.csv',
    #'data/DataAnalyst.csv',
    index_col=0,
    engine='python',
    encoding='utf-8',
)

df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          262 non-null    object
#  1   Salary Estimate    262 non-null    object
#  2   Job Description    262 non-null    object
#  3   Rating             262 non-null    float64
#  4   Company Name       262 non-null    object
#  5   Location           262 non-null    object
#  6   Size               262 non-null    object
#  7   Type of ownership  262 non-null    object
#  8   Industry           262 non-null    object
#  9   Sector             262 non-null    object
#  10  Revenue            262 non-null    object
#  11  Competitors        262 non-null    object
#  12  Easy Apply         262 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 26.7+ KB

# %% [markdown]
# # 3. EDA
# Tenemos un dataset con 262 registros sin valores nulos. En esta parte veremos columna a columna que tipo de valores tenemos, para definir las varaibles a considerar al modelo.
#
# Columnas a evaluar:
#
# - `Job Title`
# - `Salary Estimate`
# - `Job Description`
# - `Rating`
# - `Company Name`
# - `Location`
# - `Size`
# - `Type of ownership`
# - `Industry`
# - `Sector`
# - `Revenue`
# - `Competitors`
# - `Easy Apply`

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  \
# 0           Vera Institute of Justice\n3.2  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY
# 2                         Squarespace\n3.4  New York, NY
# 3                            Celerity\n4.1  New York, NY
# 4                             FanDuel\n3.9  New York, NY
#
#                      Size               Type of ownership  \
# 0    201 to 500 employees          Nonprofit Organization
# 1        10000+ employees          Nonprofit Organization
# 2  1001 to 5000 employees               Company - Private
# 3    201 to 500 employees  Subsidiary or Business Segment
# 4   501 to 1000 employees               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       TRUE
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       TRUE

# %%
df.describe(include='all')
# Out:
#            Job Title             Salary Estimate  \
# count            262                         262
# unique           169                          10
# top     Data Analyst  $43K-$76K (Glassdoor est.)
# freq              65                          31
# mean             NaN                         NaN
# std              NaN                         NaN
# min              NaN                         NaN
# 25%              NaN                         NaN
# 50%              NaN                         NaN
# 75%              NaN                         NaN
# max              NaN                         NaN
#
#                                           Job Description      Rating  \
# count                                                 262  262.000000
# unique                                                262         NaN
# top     Job Title :Senior SQL Data Analyst\n\nNo of Op...         NaN
# freq                                                    1         NaN
# mean                                                  NaN    3.103817
# std                                                   NaN    1.691081
# min                                                   NaN   -1.000000
# 25%                                                   NaN    3.100000
# 50%                                                   NaN    3.600000
# 75%                                                   NaN    4.000000
# max                                                   NaN    5.000000
#
#            Company Name      Location               Size  Type of ownership  \
# count               262           262                262                262
# unique              217            17                  9                 12
# top     Perficient\n3.6  New York, NY  1 to 50 employees  Company - Private
# freq                  5           214                 54                138
# mean                NaN           NaN                NaN                NaN
# std                 NaN           NaN                NaN                NaN
# min                 NaN           NaN                NaN                NaN
# 25%                 NaN           NaN                NaN                NaN
# 50%                 NaN           NaN                NaN                NaN
# 75%                 NaN           NaN                NaN                NaN
# max                 NaN           NaN                NaN                NaN
#
#        Industry             Sector                   Revenue Competitors  \
# count       262                262                       262         262
# unique       36                 18                        14          46
# top          -1  Business Services  Unknown / Non-Applicable          -1
# freq         47                 62                        76         207
# mean        NaN                NaN                       NaN         NaN
# std         NaN                NaN                       NaN         NaN
# min         NaN                NaN                       NaN         NaN
# 25%         NaN                NaN                       NaN         NaN
# 50%         NaN                NaN                       NaN         NaN
# 75%         NaN                NaN                       NaN         NaN
# max         NaN                NaN                       NaN         NaN
#
#        Easy Apply
# count         262
# unique          2
# top            -1
# freq          246
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
columns = [
  'Job Title',
  'Salary Estimate',
  'Job Description',
  'Rating',
  'Company Name',
  'Location',
  'Size',
  'Type of ownership',
  'Industry',
  'Sector',
  'Revenue',
  'Competitors',
  'Easy Apply',
]

df[columns].nunique()
# Out:
# Job Title            169
# Salary Estimate       10
# Job Description      262
# Rating                28
# Company Name         217
# Location              17
# Size                   9
# Type of ownership     12
# Industry              36
# Sector                18
# Revenue               14
# Competitors           46
# Easy Apply             2
# dtype: int64

# %% [markdown]
# Para cada variable notemos lo siguiente:
# - `Job Title`: título de la vacante, por los tipos de títulos existirán algunos que sean similares. Esto podría ser interesante para medir similitudes entre vacantes. (**Posible variable**)
# - `Salary Estimate`: variable a predecir, podrían tomarse los diez intervalos como clases o hacer un procesamiento para obtener un valor continuo a predecir.
# - `Job Description`: texto con la descripción del rol. (**Target**)
# - `Rating`: valor continuo entre 0-5, en Glassdoor suele ser un rating de la vacante tomada por los usuarios. Este valor puede NO aportar al modelo.
# - `Company Name`: nombre de la empresa, no aporta al modelo.
# - `Location`: Lugar de la vacante, podría ser importante como variable. Pero debido a que son muy pocas vacantes y queremos generalizar, la descartaremos.
# - `Size`: tamaño de la empresa, son pocas las categorías por lo que puede ser una buena variable a incluir en el modelo. (**Posible variable**)
# - `Type of ownership`: tipo de empresa, dado que no son muchas categorías podría ser importante para el modelo. (**Posible variable**)
# - `Industry`: industria,  dado que son demasiadas categorías lo descartaremos.
# - `Sector`: sector al que pertenece, dado que no son muchas categorías podría ser importante para el modelo. (**Posible variable**)
# - `Revenue`: intervalo de revenue de la empresa, podria ser importante para conocer las ganancias e impacto de la empresa. (**Posible variable**)
# - `Competitors`: número de competidores, no aporta al modelo.
# - `Easy Apply`: flag dado por la plataforma para la aplicación, no aporta al modelo.
#
# De esta manera, consideraremos como vriables:
#   - `Job Title`: txt a ser tratado con encoder.
#   - `Job Description`: txt a ser tratado con encoder.
#   - `Size`: txt a ser tratado con encoder.
#   - `Type of ownership`: txt a ser tratado con encoder.
#   - `Sector`: txt a ser tratado con encoder.
#   - `Revenue`: txt a ser tratado con encoder.
#
# Y como variable target: `Salary Estimate`.

# %% [markdown]
# # 4. Preprocesamiento de los datos
# Haremos el siguiente procesamiento:
# - Buscaremos predecir el promedio de los salario. Para ello haremos generaremos la target.
# - Las variables categóricas, usaremos OHE donde solo consideraremos las categorías con mayor frecuencia.
# - Para las variables `Job Title` y `Job Description` tomaremos dos encoders
#   - [JobBERT-v2](https://huggingface.co/TechWolf/JobBERT-v2) (sentence-transformersfor job title matching ): toma los títulos de los trabajos para agrupar los más parecidos. Usaremos el encoder para vectorizar el título de los trabajos.
#   - [bart-base-job-info-summarizer](https://huggingface.co/TechWolf/JobBERT-v2) (fine-tuned version of facebook/bart-base): toma descripciones de trabajos para resumirlos. Usaremos el encoder para vectorizar las descripciones de los trabajos.

# %% [markdown]
# ## 4.1 Definición de la target

# %%
df['Salary Estimate'].unique()
# Out:
# array(['$37K-$66K (Glassdoor est.)', '$46K-$87K (Glassdoor est.)',
#        '$51K-$88K (Glassdoor est.)', '$51K-$87K (Glassdoor est.)',
#        '$59K-$85K (Glassdoor est.)', '$43K-$76K (Glassdoor est.)',
#        '$60K-$110K (Glassdoor est.)', '$41K-$78K (Glassdoor est.)',
#        '$45K-$88K (Glassdoor est.)', '$73K-$127K (Glassdoor est.)'],
#       dtype=object)

# %%
# obtener max y min de los salarios

## intervalo
df.loc[:,['salary_interval']] = df['Salary Estimate'].apply(lambda x: x.split(' ')[0])

## min
df.loc[:,['salary_min']] = df['salary_interval'].apply(lambda x: x.split('-')[0])
df.loc[:,['salary_min']] = df['salary_min'].apply(lambda x: x.replace('$',''))
df.loc[:,['salary_min']] = df['salary_min'].apply(lambda x: x.replace('K',''))
df.loc[:,['salary_min']] = df.loc[:,['salary_min']].astype(int)*1000

## max
df.loc[:,['salary_max']] = df['salary_interval'].apply(lambda x: x.split('-')[1])
df.loc[:,['salary_max']] = df['salary_max'].apply(lambda x: x.replace('$',''))
df.loc[:,['salary_max']] = df['salary_max'].apply(lambda x: x.replace('K',''))
df.loc[:,['salary_max']] = df.loc[:,['salary_max']].astype(int)*1000

## mean
df.loc[:,['salary_mean']] = (df['salary_min'] + df['salary_max'])/2
df['salary_mean'] = df['salary_mean'].astype(float)

# %%
df.loc[:,['salary_mean']].describe()
# Out:
#          salary_mean
# count     262.000000
# mean    67963.740458
# std     11262.439786
# min     51500.000000
# 25%     59500.000000
# 50%     67750.000000
# 75%     72000.000000
# max    100000.000000

# %% [markdown]
# ## 4.3 Data Split

# %%
columns = [
  'Job Title',
  'Job Description',
  'Size',
  'Type of ownership',
  'Sector',
  'Revenue',
]

target = ['salary_mean']

X = df.loc[:,columns].copy()
y = df.loc[:,target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, shuffle=True)

print(f'X_train size: {X_train.shape}')
print(f'y_train size: {y_train.shape}')
print(f'X_test size: {X_test.shape}')
print(f'y_test size: {y_test.shape}')
# Out:
# X_train size: (183, 6)
# y_train size: (183, 1)
# X_test size: (79, 6)
# y_test size: (79, 1)

# %% [markdown]
# ##  4.4 ETL Orchestration
# Buscaremos hacer un ETL que realice:
# 1. Encodear con OHE las variables categóricas tomando un máximo de categorías (las más frecuentes).
# 2. Vectorizar el título de los trabajos.
# 3. Vectorizar la descripción de los trabajos.
# 4. Unir los vectores y tomar como Input de una Red Neuronal.
#
# Para realizar este ETL seguiremos la estuctura de `pipelines` de sklearn, para ello crearemos nuestros propios transformers customs y uniremos todo.

# %%
class EncodeTransformer(BaseEstimator, TransformerMixin):
    """
    Transforms text features using the JobBERT model.

    This transformer uses the JobBERT model to generate embeddings
    (vector representations) of job titles. These embeddings can be
    used as features in machine learning models.

    Attributes:
        jobbert_model_name (str): The name of the JobBERT model to use.
                                  Defaults to 'TechWolf/JobBERT-v2'.
        jobbert_model (SentenceTransformer): The instantiated JobBERT model.
                                           Initialized as None and loaded
                                           during the `fit` method.

    Examples:
        >>> encoder = EncodeTransformer()
        >>> encoder.fit(X_train)
        >>> encoded_titles = encoder.transform(X_test)
    """

    def __init__(self, jobbert_model_name='TechWolf/JobBERT-v2'):
        """
        Initializes the EncodeTransformer.

        Args:
            jobbert_model_name (str): The name of the JobBERT model to use.
        """
        self.jobbert_model_name = jobbert_model_name
        self.jobbert_model = None

    def fit(self, X, y=None):
        """
        Fits the transformer to the training data.

        This method loads the specified JobBERT model.

        Args:
            X (pd.DataFrame): The training data.
                              Must contain a 'Job Title' column.
            y (pd.Series, optional): The labels for the training data.
                                      Not used in this transformer.
                                      Defaults to None.

        Returns:
            self: The fitted EncodeTransformer object.
        """
        self.jobbert_model = SentenceTransformer(self.jobbert_model_name)
        return self

    def transform(self, X):
        """
        Transforms the input data using the JobBERT model.

        Args:
            X (pd.DataFrame): The data to transform.
                              Must contain a 'Job Title' column.

        Returns:
            np.ndarray: The embeddings generated by the JobBERT model.
        """
        X = X['Job Title'].astype(str)  # Ensure job titles are strings
        encoded_titles = self.jobbert_model.encode(X.values)
        return encoded_titles


class TokenizerTransformer(BaseEstimator, TransformerMixin):
    """
    Tokenizes text features using the AutoTokenizer tokenizer.

    This transformer uses the AutoTokenizer tokenizer to convert job
    descriptions into sequences of tokens. These token sequences can
    be used as input to language models.

    Attributes:
        tokenizer_name (str): The name of the tokenizer to use.
                              Defaults to 'avisena/bart-base-job-info-summarizer'.
        tokenizer (AutoTokenizer): The instantiated tokenizer.
                                  Initialized as None and loaded during
                                  the `fit` method.

    Examples:
        >>> tokenizer_transformer = TokenizerTransformer()
        >>> tokenizer_transformer.fit(X_train)
        >>> tokenized_descriptions = tokenizer_transformer.transform(X_test)
    """

    def __init__(self, tokenizer_name="avisena/bart-base-job-info-summarizer"):
        """
        Initializes the TokenizerTransformer.

        Args:
            tokenizer_name (str): The name of the tokenizer to use.
        """
        self.tokenizer_name = tokenizer_name
        self.tokenizer = None

    def fit(self, X, y=None):
        """
        Fits the transformer to the training data.

        This method loads the specified tokenizer.

        Args:
            X (pd.DataFrame): The training data.
                              Must contain a 'Job Description' column.
            y (pd.Series, optional): The labels for the training data.
                                      Not used in this transformer.
                                      Defaults to None.

        Returns:
            self: The fitted TokenizerTransformer object.
        """
        self.tokenizer = AutoTokenizer.from_pretrained(self.tokenizer_name)
        return self

    def transform(self, X):
        """
        Tokenizes the input data using the tokenizer.

        Args:
            X (pd.DataFrame): The data to tokenize.
                              Must contain a 'Job Description' column.

        Returns:
            np.ndarray: The token sequences generated by the tokenizer.
        """
        X = X['Job Description'].astype(str)  # Ensure descriptions are strings
        all_encoded_inputs = []
        for job_description in X.values:
            inputs = self.tokenizer.encode(
                job_description,
                return_tensors="pt",
                max_length=1024,
                truncation=True,
                padding='max_length'
            )
            all_encoded_inputs.append(inputs[0].tolist()) # Get the list of token IDs
        return np.array(all_encoded_inputs)  # Return as NumPy array

# %%
# columns by tipe
categorical_features = ['Size', 'Type of ownership', 'Sector', 'Revenue']
encode_features = ['Job Title']
tokenizer_features = ['Job Description']

##########################################
############ transformers ################
##########################################
# prepocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(sparse_output=False,max_categories=5,
                              handle_unknown='ignore'), categorical_features),
        ('job_titles', EncodeTransformer(), encode_features),
        ('job_descriptions', TokenizerTransformer(), tokenizer_features),
    ])

# etl
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()) # escalamiento de los datos
    ])

pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 max_categories=5,
#                                                                 sparse_output=False),
#                                                   ['Size', 'Type of ownership',
#                                                    'Sector', 'Revenue']),
#                                                  ('job_titles',
#                                                   EncodeTransformer(),
#                                                   ['Job Title']),
#                                                  ('job_descriptions',
#                                                   TokenizerTransformer(),
#                                                   ['Job Description'])])),
#                 ('scaler', StandardScaler())])

# %% [markdown]
# ## 4.5 Procesamiento

# %%
 # TRAIN: FIT & TRANSFORM
X_train_transfomed = pipeline.fit_transform(X_train)

# TEST: ONLY TRANSFORM
X_test_transfomed = pipeline.transform(X_test)

# %%
print(f'X_train_transformed size: {X_train_transfomed.shape}')
print(f'X_test_transformed size: {X_test_transfomed.shape}')
# Out:
# X_train_transformed size: (183, 1812)
# X_test_transformed size: (79, 1812)

# %% [markdown]
# # 5. Modelado
# Usaremos una red neuronal densa para predecir el salario.

# %%
model_nn = keras.models.Sequential([
  layers.Input((1812,), name = 'input'),
  layers.LSTM(906,  name='first_layer',  activation="tanh", kernel_regularizer=regularizers.l2(0.01)),
  layers.LSTM(452,  name='second_layer', activation="tanh", kernel_regularizer=regularizers.l2(0.01)),
  layers.Dense(226,  name='third_layer',  activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  layers.Dense(112,  name='fourth_layer', activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  layers.Dense(56,  name='fifth_layer', activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  layers.Dense(28,  name='sixth_layer', activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  layers.Dense(1, name='output')
  ]
)

model_nn.compile(
    loss='mse',
    optimizer=Adam(learning_rate=1e-3),
    metrics=['mean_absolute_error']
)


model_nn.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-67814a388db9> in <cell line: 0>()
# ----> 1 model_nn = keras.models.Sequential([
#       2   layers.Input((1812,), name = 'input'),
#       3   layers.LSTM(906,  name='first_layer',  activation="tanh", kernel_regularizer=regularizers.l2(0.01)),
#       4   layers.LSTM(452,  name='second_layer', activation="tanh", kernel_regularizer=regularizers.l2(0.01)),
#       5   layers.Dense(226,  name='third_layer',  activation="linear", kernel_regularizer=regularizers.l2(0.01)),
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in __init__(self, layers, trainable, name)
#      74             for layer in layers:
#      75                 self.add(layer, rebuild=False)
# ---> 76             self._maybe_rebuild()
#      77
#      78     def add(self, layer, rebuild=True):
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in _maybe_rebuild(self)
#     139         if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     140             input_shape = self._layers[0].batch_shape
# --> 141             self.build(input_shape)
#     142         elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     143             # We can build the Sequential model if the first layer has the
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py in build_wrapper(*args, **kwargs)
#     226             with obj._open_name_scope():
#     227                 obj._path = current_path()
# --> 228                 original_build_method(*args, **kwargs)
#     229             # Record build config.
#     230             signature = inspect.signature(original_build_method)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/models/sequential.py in build(self, input_shape)
#     185         for layer in self._layers[1:]:
#     186             try:
# --> 187                 x = layer(x)
#     188             except NotImplementedError:
#     189                 # Can happen if shape inference is not implemented.
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     184         if spec.ndim is not None and not spec.allow_last_axis_squeeze:
#     185             if ndim != spec.ndim:
# --> 186                 raise ValueError(
#     187                     f'Input {input_index} of layer "{layer_name}" '
#     188                     "is incompatible with the layer: "
#
# ValueError: Input 0 of layer "first_layer" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 1812)

# %%
# get validation datasets
X_train_, X_val_, y_train_, y_val_ = train_test_split(
    X_train_transfomed,
    y_train,
    test_size=0.4,
    random_state=42,
    shuffle=True
  )

# train
history = model_nn.fit(
    X_train_,
    y_train_['salary_mean'].values,
    epochs=150,
    batch_size = 10,
    validation_data=(X_val_, y_val_['salary_mean'].values)
)
# Out:
# Epoch 1/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 4805715456.0000 - mean_absolute_error: 68582.4531 - val_loss: 4811670528.0000 - val_mean_absolute_error: 68144.2734
# Epoch 2/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 4793457152.0000 - mean_absolute_error: 68562.7969 - val_loss: 4814125056.0000 - val_mean_absolute_error: 68161.9453
# Epoch 3/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 4568998400.0000 - mean_absolute_error: 66807.6484 - val_loss: 4871948288.0000 - val_mean_absolute_error: 68567.5000
# Epoch 4/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4575222784.0000 - mean_absolute_error: 66914.6406 - val_loss: 6935785472.0000 - val_mean_absolute_error: 80445.3906
# Epoch 5/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3265765632.0000 - mean_absolute_error: 54075.4336 - val_loss: 37185073152.0000 - val_mean_absolute_error: 165108.2812
# Epoch 6/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 3145218816.0000 - mean_absolute_error: 37315.8203 - val_loss: 17341636608.0000 - val_mean_absolute_error: 115170.2734
# Epoch 7/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1392665600.0000 - mean_absolute_error: 28638.0156 - val_loss: 28547217408.0000 - val_mean_absolute_error: 145404.4688
# Epoch 8/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 410251136.0000 - mean_absolute_error: 15414.2090 - val_loss: 31979325440.0000 - val_mean_absolute_error: 148894.9531
# Epoch 9/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 397925056.0000 - mean_absolute_error: 13539.1602 - val_loss: 31280123904.0000 - val_mean_absolute_error: 149669.9531
# Epoch 10/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 129018880.0000 - mean_absolute_error: 8876.8926 - val_loss: 35080110080.0000 - val_mean_absolute_error: 155932.2812
# Epoch 11/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 64296000.0000 - mean_absolute_error: 5373.6304 - val_loss: 32454893568.0000 - val_mean_absolute_error: 150984.3594
# Epoch 12/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 62129508.0000 - mean_absolute_error: 5703.5127 - val_loss: 34181646336.0000 - val_mean_absolute_error: 154707.5156
# Epoch 13/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 70294568.0000 - mean_absolute_error: 5397.2798 - val_loss: 32450295808.0000 - val_mean_absolute_error: 150382.4062
# Epoch 14/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 54272548.0000 - mean_absolute_error: 5010.0371 - val_loss: 35299979264.0000 - val_mean_absolute_error: 156882.0781
# Epoch 15/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 52344108.0000 - mean_absolute_error: 4920.1211 - val_loss: 31852519424.0000 - val_mean_absolute_error: 148996.4844
# Epoch 16/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 70961640.0000 - mean_absolute_error: 5125.1045 - val_loss: 35746705408.0000 - val_mean_absolute_error: 158001.1875
# Epoch 17/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 52473884.0000 - mean_absolute_error: 4563.8823 - val_loss: 32996675584.0000 - val_mean_absolute_error: 151219.9531
# Epoch 18/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 34804728.0000 - mean_absolute_error: 3924.0457 - val_loss: 34336178176.0000 - val_mean_absolute_error: 154979.3125
# Epoch 19/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 18429612.0000 - mean_absolute_error: 2887.6787 - val_loss: 33831032832.0000 - val_mean_absolute_error: 153508.1250
# Epoch 20/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 9098395.0000 - mean_absolute_error: 2306.8743 - val_loss: 34104399872.0000 - val_mean_absolute_error: 154141.1406
# Epoch 21/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 14140780.0000 - mean_absolute_error: 2131.9097 - val_loss: 34748313600.0000 - val_mean_absolute_error: 154979.6875
# Epoch 22/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 10288842.0000 - mean_absolute_error: 1974.7385 - val_loss: 33171716096.0000 - val_mean_absolute_error: 152787.8438
# Epoch 23/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 11907791.0000 - mean_absolute_error: 2213.7314 - val_loss: 34178762752.0000 - val_mean_absolute_error: 153598.2344
# Epoch 24/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 14887843.0000 - mean_absolute_error: 2460.7729 - val_loss: 34568339456.0000 - val_mean_absolute_error: 155424.9844
# Epoch 25/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 11522787.0000 - mean_absolute_error: 2177.7529 - val_loss: 33154686976.0000 - val_mean_absolute_error: 151592.2812
# Epoch 26/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 15095560.0000 - mean_absolute_error: 2536.6343 - val_loss: 35356164096.0000 - val_mean_absolute_error: 157194.0938
# Epoch 27/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 25664208.0000 - mean_absolute_error: 3852.9187 - val_loss: 32133515264.0000 - val_mean_absolute_error: 149119.5156
# Epoch 28/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 47601960.0000 - mean_absolute_error: 5234.9023 - val_loss: 34622717952.0000 - val_mean_absolute_error: 156242.5156
# Epoch 29/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 63530196.0000 - mean_absolute_error: 5671.1748 - val_loss: 31611846656.0000 - val_mean_absolute_error: 148396.2969
# Epoch 30/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 139369232.0000 - mean_absolute_error: 8241.1211 - val_loss: 37111812096.0000 - val_mean_absolute_error: 161113.6406
# Epoch 31/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 120588128.0000 - mean_absolute_error: 8195.5527 - val_loss: 27730634752.0000 - val_mean_absolute_error: 140819.0156
# Epoch 32/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 246102176.0000 - mean_absolute_error: 11254.1396 - val_loss: 39150718976.0000 - val_mean_absolute_error: 163022.6406
# Epoch 33/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 216894080.0000 - mean_absolute_error: 11754.6094 - val_loss: 27970797568.0000 - val_mean_absolute_error: 142574.7031
# Epoch 34/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 234092384.0000 - mean_absolute_error: 10967.3359 - val_loss: 36355899392.0000 - val_mean_absolute_error: 156616.2188
# Epoch 35/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 323920928.0000 - mean_absolute_error: 11768.2979 - val_loss: 29226051584.0000 - val_mean_absolute_error: 147198.0938
# Epoch 36/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 165871008.0000 - mean_absolute_error: 9814.8477 - val_loss: 34421301248.0000 - val_mean_absolute_error: 152444.6094
# Epoch 37/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 81303680.0000 - mean_absolute_error: 7109.3120 - val_loss: 35726966784.0000 - val_mean_absolute_error: 158985.9531
# Epoch 38/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 102996712.0000 - mean_absolute_error: 8042.4600 - val_loss: 30425315328.0000 - val_mean_absolute_error: 145929.1875
# Epoch 39/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 70038224.0000 - mean_absolute_error: 6323.2217 - val_loss: 35482959872.0000 - val_mean_absolute_error: 157470.9844
# Epoch 40/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 51651908.0000 - mean_absolute_error: 5592.0342 - val_loss: 31310168064.0000 - val_mean_absolute_error: 148823.4219
# Epoch 41/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 35927092.0000 - mean_absolute_error: 3834.0288 - val_loss: 33833037824.0000 - val_mean_absolute_error: 153780.0781
# Epoch 42/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 14040632.0000 - mean_absolute_error: 2851.3926 - val_loss: 33489012736.0000 - val_mean_absolute_error: 153258.2031
# Epoch 43/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 11399465.0000 - mean_absolute_error: 2134.5125 - val_loss: 32982720512.0000 - val_mean_absolute_error: 151555.7031
# Epoch 44/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 7781743.5000 - mean_absolute_error: 1964.0166 - val_loss: 33538494464.0000 - val_mean_absolute_error: 153378.8281
# Epoch 45/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8007757.5000 - mean_absolute_error: 2236.8755 - val_loss: 33013161984.0000 - val_mean_absolute_error: 152012.7500
# Epoch 46/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 6350206.5000 - mean_absolute_error: 1623.8774 - val_loss: 33834450944.0000 - val_mean_absolute_error: 153888.6406
# Epoch 47/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 5776882.5000 - mean_absolute_error: 1639.4711 - val_loss: 33822867456.0000 - val_mean_absolute_error: 153521.2500
# Epoch 48/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 3503433.7500 - mean_absolute_error: 1357.6625 - val_loss: 33178605568.0000 - val_mean_absolute_error: 152431.8906
# Epoch 49/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 3858678.2500 - mean_absolute_error: 1348.5037 - val_loss: 33054449664.0000 - val_mean_absolute_error: 152042.2500
# Epoch 50/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 6201137.5000 - mean_absolute_error: 1597.4612 - val_loss: 33888753664.0000 - val_mean_absolute_error: 153886.9531
# Epoch 51/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 3824317.7500 - mean_absolute_error: 1313.2939 - val_loss: 34370912256.0000 - val_mean_absolute_error: 154445.3125
# Epoch 52/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3565801.0000 - mean_absolute_error: 1575.0807 - val_loss: 32002723840.0000 - val_mean_absolute_error: 150171.9062
# Epoch 53/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 5789589.5000 - mean_absolute_error: 2023.3069 - val_loss: 33421113344.0000 - val_mean_absolute_error: 152670.5469
# Epoch 54/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 2915623.2500 - mean_absolute_error: 1333.0732 - val_loss: 34106511360.0000 - val_mean_absolute_error: 154258.6406
# Epoch 55/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 4296284.0000 - mean_absolute_error: 1568.8708 - val_loss: 33085597696.0000 - val_mean_absolute_error: 152208.2344
# Epoch 56/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 4898094.0000 - mean_absolute_error: 1588.8698 - val_loss: 32872914944.0000 - val_mean_absolute_error: 151650.9844
# Epoch 57/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4748149.0000 - mean_absolute_error: 1706.1583 - val_loss: 34461044736.0000 - val_mean_absolute_error: 154884.3281
# Epoch 58/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3807939.0000 - mean_absolute_error: 1437.4109 - val_loss: 33275977728.0000 - val_mean_absolute_error: 152442.2344
# Epoch 59/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4255337.5000 - mean_absolute_error: 1394.2565 - val_loss: 33122875392.0000 - val_mean_absolute_error: 152587.0469
# Epoch 60/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 13411780.0000 - mean_absolute_error: 1669.6809 - val_loss: 34376921088.0000 - val_mean_absolute_error: 154276.9375
# Epoch 61/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 15717649.0000 - mean_absolute_error: 2177.5737 - val_loss: 32142399488.0000 - val_mean_absolute_error: 150920.7188
# Epoch 62/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 13738554.0000 - mean_absolute_error: 2877.9441 - val_loss: 33981706240.0000 - val_mean_absolute_error: 153545.0000
# Epoch 63/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 31449958.0000 - mean_absolute_error: 3132.4233 - val_loss: 34443272192.0000 - val_mean_absolute_error: 155468.8438
# Epoch 64/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 30102302.0000 - mean_absolute_error: 3333.2776 - val_loss: 34619101184.0000 - val_mean_absolute_error: 154510.7188
# Epoch 65/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 37460924.0000 - mean_absolute_error: 4634.3540 - val_loss: 30489477120.0000 - val_mean_absolute_error: 147355.9844
# Epoch 66/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 30408374.0000 - mean_absolute_error: 4492.8984 - val_loss: 32853948416.0000 - val_mean_absolute_error: 151456.7500
# Epoch 67/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 22323312.0000 - mean_absolute_error: 3455.9646 - val_loss: 33422934016.0000 - val_mean_absolute_error: 153296.8125
# Epoch 68/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 37990596.0000 - mean_absolute_error: 4825.7690 - val_loss: 33739268096.0000 - val_mean_absolute_error: 153288.8438
# Epoch 69/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 29797468.0000 - mean_absolute_error: 3936.4312 - val_loss: 32671694848.0000 - val_mean_absolute_error: 151634.6562
# Epoch 70/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 28324928.0000 - mean_absolute_error: 4091.7039 - val_loss: 31406059520.0000 - val_mean_absolute_error: 148507.2812
# Epoch 71/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 54999948.0000 - mean_absolute_error: 4969.6460 - val_loss: 33043615744.0000 - val_mean_absolute_error: 152832.7500
# Epoch 72/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 83459208.0000 - mean_absolute_error: 6754.7778 - val_loss: 34777288704.0000 - val_mean_absolute_error: 154431.7500
# Epoch 73/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 238979488.0000 - mean_absolute_error: 8616.2412 - val_loss: 33241782272.0000 - val_mean_absolute_error: 153688.6250
# Epoch 74/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 92665056.0000 - mean_absolute_error: 6983.1211 - val_loss: 32828327936.0000 - val_mean_absolute_error: 150563.0156
# Epoch 75/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 107305312.0000 - mean_absolute_error: 8117.5439 - val_loss: 28174051328.0000 - val_mean_absolute_error: 144284.3438
# Epoch 76/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 97716576.0000 - mean_absolute_error: 7774.3408 - val_loss: 30930051072.0000 - val_mean_absolute_error: 146743.0781
# Epoch 77/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 69598616.0000 - mean_absolute_error: 6121.9678 - val_loss: 32210831360.0000 - val_mean_absolute_error: 152189.8438
# Epoch 78/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 92651216.0000 - mean_absolute_error: 7628.7280 - val_loss: 32502781952.0000 - val_mean_absolute_error: 149592.4531
# Epoch 79/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 97131352.0000 - mean_absolute_error: 6728.0220 - val_loss: 32736557056.0000 - val_mean_absolute_error: 152619.0469
# Epoch 80/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 53752148.0000 - mean_absolute_error: 5180.4521 - val_loss: 30397714432.0000 - val_mean_absolute_error: 145881.8125
# Epoch 81/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 79000968.0000 - mean_absolute_error: 6399.1587 - val_loss: 31242002432.0000 - val_mean_absolute_error: 149555.2344
# Epoch 82/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 56313260.0000 - mean_absolute_error: 5221.5259 - val_loss: 29384720384.0000 - val_mean_absolute_error: 143506.9219
# Epoch 83/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 134264640.0000 - mean_absolute_error: 7851.4111 - val_loss: 33505103872.0000 - val_mean_absolute_error: 154117.6719
# Epoch 84/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 66215048.0000 - mean_absolute_error: 5542.2236 - val_loss: 31215300608.0000 - val_mean_absolute_error: 148022.9062
# Epoch 85/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 53127596.0000 - mean_absolute_error: 4499.3950 - val_loss: 33073471488.0000 - val_mean_absolute_error: 152828.7344
# Epoch 86/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 61090388.0000 - mean_absolute_error: 5707.4087 - val_loss: 31221995520.0000 - val_mean_absolute_error: 148288.8438
# Epoch 87/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 75706440.0000 - mean_absolute_error: 5798.1846 - val_loss: 31564929024.0000 - val_mean_absolute_error: 149437.4375
# Epoch 88/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 27918018.0000 - mean_absolute_error: 4051.0303 - val_loss: 31704317952.0000 - val_mean_absolute_error: 149357.3438
# Epoch 89/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 29222294.0000 - mean_absolute_error: 3999.1853 - val_loss: 33425432576.0000 - val_mean_absolute_error: 153088.2969
# Epoch 90/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 27096840.0000 - mean_absolute_error: 3769.4727 - val_loss: 33530421248.0000 - val_mean_absolute_error: 152785.3281
# Epoch 91/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 12697621.0000 - mean_absolute_error: 2763.4519 - val_loss: 34538377216.0000 - val_mean_absolute_error: 155139.3125
# Epoch 92/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 22264110.0000 - mean_absolute_error: 3698.3472 - val_loss: 32166821888.0000 - val_mean_absolute_error: 150347.8438
# Epoch 93/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 26101112.0000 - mean_absolute_error: 4093.5059 - val_loss: 31173994496.0000 - val_mean_absolute_error: 148609.4531
# Epoch 94/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 21901132.0000 - mean_absolute_error: 3782.4658 - val_loss: 32239794176.0000 - val_mean_absolute_error: 150790.1719
# Epoch 95/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 22415026.0000 - mean_absolute_error: 3605.5083 - val_loss: 34025302016.0000 - val_mean_absolute_error: 154202.5469
# Epoch 96/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 22959546.0000 - mean_absolute_error: 3582.1187 - val_loss: 33662576640.0000 - val_mean_absolute_error: 152875.4844
# Epoch 97/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 22447328.0000 - mean_absolute_error: 3300.3906 - val_loss: 32411703296.0000 - val_mean_absolute_error: 151467.2812
# Epoch 98/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 23721686.0000 - mean_absolute_error: 3092.1809 - val_loss: 32881410048.0000 - val_mean_absolute_error: 151522.5156
# Epoch 99/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 18566978.0000 - mean_absolute_error: 2758.2939 - val_loss: 33983911936.0000 - val_mean_absolute_error: 154247.3750
# Epoch 100/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 10316482.0000 - mean_absolute_error: 2460.2068 - val_loss: 33098156032.0000 - val_mean_absolute_error: 152228.0625
# Epoch 101/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 8658620.0000 - mean_absolute_error: 2025.6849 - val_loss: 31885967360.0000 - val_mean_absolute_error: 150201.9062
# Epoch 102/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 5456141.5000 - mean_absolute_error: 1865.5680 - val_loss: 31757664256.0000 - val_mean_absolute_error: 149616.5312
# Epoch 103/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 5417196.0000 - mean_absolute_error: 1879.6798 - val_loss: 33865717760.0000 - val_mean_absolute_error: 153908.8594
# Epoch 104/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 8158283.0000 - mean_absolute_error: 2206.1521 - val_loss: 33686480896.0000 - val_mean_absolute_error: 153166.2969
# Epoch 105/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 5636586.0000 - mean_absolute_error: 1890.2469 - val_loss: 33193527296.0000 - val_mean_absolute_error: 152612.3438
# Epoch 106/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 4323037.0000 - mean_absolute_error: 1619.1453 - val_loss: 34002339840.0000 - val_mean_absolute_error: 153734.9531
# Epoch 107/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 9566322.0000 - mean_absolute_error: 2350.6643 - val_loss: 34676973568.0000 - val_mean_absolute_error: 155767.3594
# Epoch 108/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 14823645.0000 - mean_absolute_error: 3069.0791 - val_loss: 33467211776.0000 - val_mean_absolute_error: 152454.7812
# Epoch 109/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 22185806.0000 - mean_absolute_error: 3494.9092 - val_loss: 32980525056.0000 - val_mean_absolute_error: 152409.9219
# Epoch 110/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 43727908.0000 - mean_absolute_error: 3966.0669 - val_loss: 30863906816.0000 - val_mean_absolute_error: 147714.0000
# Epoch 111/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 38634232.0000 - mean_absolute_error: 4318.5957 - val_loss: 32516745216.0000 - val_mean_absolute_error: 151444.2812
# Epoch 112/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 25061854.0000 - mean_absolute_error: 4022.1550 - val_loss: 33574205440.0000 - val_mean_absolute_error: 152944.6250
# Epoch 113/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 26500986.0000 - mean_absolute_error: 3522.7622 - val_loss: 33747777536.0000 - val_mean_absolute_error: 153727.5938
# Epoch 114/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 23643040.0000 - mean_absolute_error: 3466.3411 - val_loss: 33572569088.0000 - val_mean_absolute_error: 153076.2656
# Epoch 115/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 15672100.0000 - mean_absolute_error: 2554.3228 - val_loss: 30952697856.0000 - val_mean_absolute_error: 148434.1875
# Epoch 116/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 20402404.0000 - mean_absolute_error: 3400.0066 - val_loss: 31850117120.0000 - val_mean_absolute_error: 149406.7344
# Epoch 117/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 23270160.0000 - mean_absolute_error: 3720.8604 - val_loss: 32264284160.0000 - val_mean_absolute_error: 150891.1875
# Epoch 118/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 13867536.0000 - mean_absolute_error: 2847.4333 - val_loss: 33033881600.0000 - val_mean_absolute_error: 152262.0469
# Epoch 119/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 11557507.0000 - mean_absolute_error: 2515.5320 - val_loss: 31773241344.0000 - val_mean_absolute_error: 149406.2344
# Epoch 120/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 7523547.5000 - mean_absolute_error: 2027.5847 - val_loss: 32256624640.0000 - val_mean_absolute_error: 151085.5625
# Epoch 121/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 14552487.0000 - mean_absolute_error: 2614.5173 - val_loss: 31892807680.0000 - val_mean_absolute_error: 149584.7812
# Epoch 122/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 28572590.0000 - mean_absolute_error: 3813.8447 - val_loss: 31131006976.0000 - val_mean_absolute_error: 149136.4219
# Epoch 123/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 27022526.0000 - mean_absolute_error: 3417.2229 - val_loss: 31264661504.0000 - val_mean_absolute_error: 147816.4375
# Epoch 124/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 54104976.0000 - mean_absolute_error: 5189.9751 - val_loss: 32469329920.0000 - val_mean_absolute_error: 152293.8438
# Epoch 125/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 35106496.0000 - mean_absolute_error: 3948.9351 - val_loss: 30279407616.0000 - val_mean_absolute_error: 145874.8125
# Epoch 126/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 52644668.0000 - mean_absolute_error: 5430.3018 - val_loss: 29758601216.0000 - val_mean_absolute_error: 146896.0000
# Epoch 127/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 52653360.0000 - mean_absolute_error: 6119.3750 - val_loss: 32029302784.0000 - val_mean_absolute_error: 148921.2969
# Epoch 128/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 48034680.0000 - mean_absolute_error: 5027.1973 - val_loss: 35133235200.0000 - val_mean_absolute_error: 156877.7500
# Epoch 129/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 71245640.0000 - mean_absolute_error: 6784.6831 - val_loss: 37128720384.0000 - val_mean_absolute_error: 158932.6562
# Epoch 130/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 93146344.0000 - mean_absolute_error: 8088.4780 - val_loss: 33676236800.0000 - val_mean_absolute_error: 153675.3125
# Epoch 131/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 63254244.0000 - mean_absolute_error: 5545.9180 - val_loss: 34514051072.0000 - val_mean_absolute_error: 154924.5469
# Epoch 132/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 76389400.0000 - mean_absolute_error: 5330.1162 - val_loss: 31965151232.0000 - val_mean_absolute_error: 151070.0000
# Epoch 133/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 64339944.0000 - mean_absolute_error: 5995.3433 - val_loss: 35550003200.0000 - val_mean_absolute_error: 156447.6875
# Epoch 134/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 157638256.0000 - mean_absolute_error: 7301.0527 - val_loss: 35777286144.0000 - val_mean_absolute_error: 158015.4531
# Epoch 135/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 121476048.0000 - mean_absolute_error: 8140.7554 - val_loss: 38668304384.0000 - val_mean_absolute_error: 162283.1562
# Epoch 136/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 174700064.0000 - mean_absolute_error: 9905.6670 - val_loss: 36217458688.0000 - val_mean_absolute_error: 158690.3594
# Epoch 137/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 174162160.0000 - mean_absolute_error: 9052.3350 - val_loss: 38772371456.0000 - val_mean_absolute_error: 162695.2656
# Epoch 138/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 185401600.0000 - mean_absolute_error: 10348.3975 - val_loss: 33730918400.0000 - val_mean_absolute_error: 153341.9844
# Epoch 139/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 90387872.0000 - mean_absolute_error: 7261.1265 - val_loss: 30722838528.0000 - val_mean_absolute_error: 147326.2344
# Epoch 140/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 56647824.0000 - mean_absolute_error: 5430.8237 - val_loss: 30857801728.0000 - val_mean_absolute_error: 148864.9688
# Epoch 141/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 62054024.0000 - mean_absolute_error: 5657.0708 - val_loss: 31651684352.0000 - val_mean_absolute_error: 149222.4531
# Epoch 142/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 48125116.0000 - mean_absolute_error: 4382.3867 - val_loss: 27680315392.0000 - val_mean_absolute_error: 141963.9844
# Epoch 143/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 43959036.0000 - mean_absolute_error: 5461.0938 - val_loss: 32356564992.0000 - val_mean_absolute_error: 151405.1875
# Epoch 144/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 40960944.0000 - mean_absolute_error: 4111.1152 - val_loss: 32398594048.0000 - val_mean_absolute_error: 150894.0000
# Epoch 145/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 13433550.0000 - mean_absolute_error: 2861.8625 - val_loss: 33191356416.0000 - val_mean_absolute_error: 153080.8750
# Epoch 146/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 13264988.0000 - mean_absolute_error: 2573.7605 - val_loss: 32308557824.0000 - val_mean_absolute_error: 150248.7500
# Epoch 147/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 16725175.0000 - mean_absolute_error: 3270.1304 - val_loss: 31260895232.0000 - val_mean_absolute_error: 149150.7500
# Epoch 148/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 19953556.0000 - mean_absolute_error: 3510.5522 - val_loss: 33350402048.0000 - val_mean_absolute_error: 152449.1875
# Epoch 149/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 14069911.0000 - mean_absolute_error: 3084.6013 - val_loss: 35621933056.0000 - val_mean_absolute_error: 157224.5000
# Epoch 150/150
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 32163430.0000 - mean_absolute_error: 4657.7798 - val_loss: 33636589568.0000 - val_mean_absolute_error: 153283.5469

# %% [markdown]
# # 6. Evaluación

# %%
# Graficar la función de pérdida
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Entrenamiento', color='turquoise')
plt.title('Función de Pérdida del Modelo')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# %%
y_train_pred = model_nn.predict(X_train_transfomed)
y_test_pred = model_nn.predict(X_test_transfomed)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
# metrics
rmse = mean_squared_error(y_train, y_train_pred)**0.5
mae = mean_absolute_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print('Train Metrics:')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'MAE: {r2:.4f}')

print('-'*20)

rmse = mean_squared_error(y_test, y_test_pred)**0.5
mae = mean_absolute_error(y_test, y_test_pred)
r2 = r2_score(y_test, y_test_pred)

print('Test Metrics:')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'MAE: {r2:.4f}')
# Out:
# Train Metrics:
# RMSE: 116674.1020
# MAE: 64077.8906
# MAE: -101.8099
# --------------------
# Test Metrics:
# RMSE: 91626.7182
# MAE: 71276.8438
# MAE: -73.7740
