# %% [markdown]
# # **Aplicaciones Financieras de ML & AI**
# ## **Examen III:** *AI in Finance*
#
# #### Nombre: Julio César Avila Torreblanca
#
# - **Problema:**
#     * Genere un modelo que dato un texto, nos regrese como predicción un salario estimado o un rango salarial estimado (use al menos 3 variables).
#         - Use un modelo o variante de Bert.
#     * Base de datos: consiste en Empleos, Descripciones de los empleos y Rango salarial.
#
#
# - **Contenido del notebook**:
#     1. Librerías y parámetros
#     2. Lectura de datos
#     3. EDA
#     4. Procesamiento de datos
#     5. Modelado
#     6. Evaluación

# %% [markdown]
# # 1. Librerías y parámetros

# %%
# data manipulation
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin

# nn
from transformers import  AutoTokenizer
from sentence_transformers import SentenceTransformer
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, regularizers

# test
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# visualization
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Lectura de datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(
    '/content/drive/MyDrive/Academy/Diplomado_Finanazas&IA/01_Aplicaciones_Financieras_ML&AI/Tests/DataAnalyst.csv',
    #'data/DataAnalyst.csv',
    index_col=0,
    engine='python',
    encoding='utf-8',
)

df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          262 non-null    object
#  1   Salary Estimate    262 non-null    object
#  2   Job Description    262 non-null    object
#  3   Rating             262 non-null    float64
#  4   Company Name       262 non-null    object
#  5   Location           262 non-null    object
#  6   Size               262 non-null    object
#  7   Type of ownership  262 non-null    object
#  8   Industry           262 non-null    object
#  9   Sector             262 non-null    object
#  10  Revenue            262 non-null    object
#  11  Competitors        262 non-null    object
#  12  Easy Apply         262 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 26.7+ KB

# %% [markdown]
# # 3. EDA
# Tenemos un dataset con 262 registros sin valores nulos. En esta parte veremos columna a columna que tipo de valores tenemos, para definir las varaibles a considerar al modelo.
#
# Columnas a evaluar:
#
# - `Job Title`
# - `Salary Estimate`
# - `Job Description`
# - `Rating`
# - `Company Name`
# - `Location`
# - `Size`
# - `Type of ownership`
# - `Industry`
# - `Sector`
# - `Revenue`
# - `Competitors`
# - `Easy Apply`

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  \
# 0           Vera Institute of Justice\n3.2  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY
# 2                         Squarespace\n3.4  New York, NY
# 3                            Celerity\n4.1  New York, NY
# 4                             FanDuel\n3.9  New York, NY
#
#                      Size               Type of ownership  \
# 0    201 to 500 employees          Nonprofit Organization
# 1        10000+ employees          Nonprofit Organization
# 2  1001 to 5000 employees               Company - Private
# 3    201 to 500 employees  Subsidiary or Business Segment
# 4   501 to 1000 employees               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       TRUE
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       TRUE

# %%
df.describe(include='all')
# Out:
#            Job Title             Salary Estimate  \
# count            262                         262
# unique           169                          10
# top     Data Analyst  $43K-$76K (Glassdoor est.)
# freq              65                          31
# mean             NaN                         NaN
# std              NaN                         NaN
# min              NaN                         NaN
# 25%              NaN                         NaN
# 50%              NaN                         NaN
# 75%              NaN                         NaN
# max              NaN                         NaN
#
#                                           Job Description      Rating  \
# count                                                 262  262.000000
# unique                                                262         NaN
# top     Job Title :Senior SQL Data Analyst\n\nNo of Op...         NaN
# freq                                                    1         NaN
# mean                                                  NaN    3.103817
# std                                                   NaN    1.691081
# min                                                   NaN   -1.000000
# 25%                                                   NaN    3.100000
# 50%                                                   NaN    3.600000
# 75%                                                   NaN    4.000000
# max                                                   NaN    5.000000
#
#            Company Name      Location               Size  Type of ownership  \
# count               262           262                262                262
# unique              217            17                  9                 12
# top     Perficient\n3.6  New York, NY  1 to 50 employees  Company - Private
# freq                  5           214                 54                138
# mean                NaN           NaN                NaN                NaN
# std                 NaN           NaN                NaN                NaN
# min                 NaN           NaN                NaN                NaN
# 25%                 NaN           NaN                NaN                NaN
# 50%                 NaN           NaN                NaN                NaN
# 75%                 NaN           NaN                NaN                NaN
# max                 NaN           NaN                NaN                NaN
#
#        Industry             Sector                   Revenue Competitors  \
# count       262                262                       262         262
# unique       36                 18                        14          46
# top          -1  Business Services  Unknown / Non-Applicable          -1
# freq         47                 62                        76         207
# mean        NaN                NaN                       NaN         NaN
# std         NaN                NaN                       NaN         NaN
# min         NaN                NaN                       NaN         NaN
# 25%         NaN                NaN                       NaN         NaN
# 50%         NaN                NaN                       NaN         NaN
# 75%         NaN                NaN                       NaN         NaN
# max         NaN                NaN                       NaN         NaN
#
#        Easy Apply
# count         262
# unique          2
# top            -1
# freq          246
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
columns = [
  'Job Title',
  'Salary Estimate',
  'Job Description',
  'Rating',
  'Company Name',
  'Location',
  'Size',
  'Type of ownership',
  'Industry',
  'Sector',
  'Revenue',
  'Competitors',
  'Easy Apply',
]

df[columns].nunique()
# Out:
# Job Title            169
# Salary Estimate       10
# Job Description      262
# Rating                28
# Company Name         217
# Location              17
# Size                   9
# Type of ownership     12
# Industry              36
# Sector                18
# Revenue               14
# Competitors           46
# Easy Apply             2
# dtype: int64

# %% [markdown]
# Para cada variable notemos lo siguiente:
# - `Job Title`: título de la vacante, por los tipos de títulos existirán algunos que sean similares. Esto podría ser interesante para medir similitudes entre vacantes. (**Posible variable**)
# - `Salary Estimate`: variable a predecir, podrían tomarse los diez intervalos como clases o hacer un procesamiento para obtener un valor continuo a predecir.
# - `Job Description`: texto con la descripción del rol. (**Target**)
# - `Rating`: valor continuo entre 0-5, en Glassdoor suele ser un rating de la vacante tomada por los usuarios. Este valor puede NO aportar al modelo.
# - `Company Name`: nombre de la empresa, no aporta al modelo.
# - `Location`: Lugar de la vacante, podría ser importante como variable. Pero debido a que son muy pocas vacantes y queremos generalizar, la descartaremos.
# - `Size`: tamaño de la empresa, son pocas las categorías por lo que puede ser una buena variable a incluir en el modelo. (**Posible variable**)
# - `Type of ownership`: tipo de empresa, dado que no son muchas categorías podría ser importante para el modelo. (**Posible variable**)
# - `Industry`: industria,  dado que son demasiadas categorías lo descartaremos.
# - `Sector`: sector al que pertenece, dado que no son muchas categorías podría ser importante para el modelo. (**Posible variable**)
# - `Revenue`: intervalo de revenue de la empresa, podria ser importante para conocer las ganancias e impacto de la empresa. (**Posible variable**)
# - `Competitors`: número de competidores, no aporta al modelo.
# - `Easy Apply`: flag dado por la plataforma para la aplicación, no aporta al modelo.
#
# De esta manera, consideraremos como vriables:
#   - `Job Title`: txt a ser tratado con encoder.
#   - `Job Description`: txt a ser tratado con encoder.
#   - `Size`: txt a ser tratado con encoder.
#   - `Type of ownership`: txt a ser tratado con encoder.
#   - `Sector`: txt a ser tratado con encoder.
#   - `Revenue`: txt a ser tratado con encoder.
#
# Y como variable target: `Salary Estimate`.

# %% [markdown]
# # 4. Preprocesamiento de los datos
# Haremos el siguiente procesamiento:
# - Buscaremos predecir el promedio de los salario. Para ello haremos generaremos la target.
# - Las variables categóricas, usaremos OHE donde solo consideraremos las categorías con mayor frecuencia.
# - Para las variables `Job Title` y `Job Description` tomaremos dos encoders
#   - [JobBERT-v2](https://huggingface.co/TechWolf/JobBERT-v2) (sentence-transformersfor job title matching ): toma los títulos de los trabajos para agrupar los más parecidos. Usaremos el encoder para vectorizar el título de los trabajos.
#   - [bart-base-job-info-summarizer](https://huggingface.co/TechWolf/JobBERT-v2) (fine-tuned version of facebook/bart-base): toma descripciones de trabajos para resumirlos. Usaremos el encoder para vectorizar las descripciones de los trabajos.

# %% [markdown]
# ## 4.1 Definición de la target

# %%
df['Salary Estimate'].unique()
# Out:
# array(['$37K-$66K (Glassdoor est.)', '$46K-$87K (Glassdoor est.)',
#        '$51K-$88K (Glassdoor est.)', '$51K-$87K (Glassdoor est.)',
#        '$59K-$85K (Glassdoor est.)', '$43K-$76K (Glassdoor est.)',
#        '$60K-$110K (Glassdoor est.)', '$41K-$78K (Glassdoor est.)',
#        '$45K-$88K (Glassdoor est.)', '$73K-$127K (Glassdoor est.)'],
#       dtype=object)

# %%
# obtener max y min de los salarios

## intervalo
df.loc[:,['salary_interval']] = df['Salary Estimate'].apply(lambda x: x.split(' ')[0])

## min
df.loc[:,['salary_min']] = df['salary_interval'].apply(lambda x: x.split('-')[0])
df.loc[:,['salary_min']] = df['salary_min'].apply(lambda x: x.replace('$',''))
df.loc[:,['salary_min']] = df['salary_min'].apply(lambda x: x.replace('K',''))
df.loc[:,['salary_min']] = df.loc[:,['salary_min']].astype(int)*1000

## max
df.loc[:,['salary_max']] = df['salary_interval'].apply(lambda x: x.split('-')[1])
df.loc[:,['salary_max']] = df['salary_max'].apply(lambda x: x.replace('$',''))
df.loc[:,['salary_max']] = df['salary_max'].apply(lambda x: x.replace('K',''))
df.loc[:,['salary_max']] = df.loc[:,['salary_max']].astype(int)*1000

## mean
df.loc[:,['salary_mean']] = (df['salary_min'] + df['salary_max'])/2
df['salary_mean'] = df['salary_mean'].astype(float)

# %%
df.loc[:,['salary_mean']].describe()
# Out:
#          salary_mean
# count     262.000000
# mean    67963.740458
# std     11262.439786
# min     51500.000000
# 25%     59500.000000
# 50%     67750.000000
# 75%     72000.000000
# max    100000.000000

# %% [markdown]
# ## 4.3 Data Split

# %%
columns = [
  'Job Title',
  'Job Description',
  'Size',
  'Type of ownership',
  'Sector',
  'Revenue',
]

target = ['salary_mean','salary_max']

X = df.loc[:,columns].copy()
y = df.loc[:,target].copy()

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, shuffle=True)

print(f'X_train size: {X_train.shape}')
print(f'y_train size: {y_train.shape}')
print(f'X_test size: {X_test.shape}')
print(f'y_test size: {y_test.shape}')
# Out:
# X_train size: (183, 6)
# y_train size: (183, 2)
# X_test size: (79, 6)
# y_test size: (79, 2)

# %% [markdown]
# ##  4.4 ETL Orchestration
# Buscaremos hacer un ETL que realice:
# 1. Encodear con OHE las variables categóricas tomando un máximo de categorías (las más frecuentes).
# 2. Vectorizar el título de los trabajos.
# 3. Vectorizar la descripción de los trabajos.
# 4. Unir los vectores y tomar como Input de una Red Neuronal.
#
# Para realizar este ETL seguiremos la estuctura de `pipelines` de sklearn, para ello crearemos nuestros propios transformers customs y uniremos todo.

# %%
class EncodeTransformer(BaseEstimator, TransformerMixin):
    """
    Transforms text features using the JobBERT model.

    This transformer uses the JobBERT model to generate embeddings
    (vector representations) of job titles. These embeddings can be
    used as features in machine learning models.

    Attributes:
        jobbert_model_name (str): The name of the JobBERT model to use.
                                  Defaults to 'TechWolf/JobBERT-v2'.
        jobbert_model (SentenceTransformer): The instantiated JobBERT model.
                                           Initialized as None and loaded
                                           during the `fit` method.

    Examples:
        >>> encoder = EncodeTransformer()
        >>> encoder.fit(X_train)
        >>> encoded_titles = encoder.transform(X_test)
    """

    def __init__(self, jobbert_model_name='TechWolf/JobBERT-v2'):
        """
        Initializes the EncodeTransformer.

        Args:
            jobbert_model_name (str): The name of the JobBERT model to use.
        """
        self.jobbert_model_name = jobbert_model_name
        self.jobbert_model = None

    def fit(self, X, y=None):
        """
        Fits the transformer to the training data.

        This method loads the specified JobBERT model.

        Args:
            X (pd.DataFrame): The training data.
                              Must contain a 'Job Title' column.
            y (pd.Series, optional): The labels for the training data.
                                      Not used in this transformer.
                                      Defaults to None.

        Returns:
            self: The fitted EncodeTransformer object.
        """
        self.jobbert_model = SentenceTransformer(self.jobbert_model_name)
        return self

    def transform(self, X):
        """
        Transforms the input data using the JobBERT model.

        Args:
            X (pd.DataFrame): The data to transform.
                              Must contain a 'Job Title' column.

        Returns:
            np.ndarray: The embeddings generated by the JobBERT model.
        """
        X = X['Job Title'].astype(str)  # Ensure job titles are strings
        encoded_titles = self.jobbert_model.encode(X.values)
        return encoded_titles


class TokenizerTransformer(BaseEstimator, TransformerMixin):
    """
    Tokenizes text features using the AutoTokenizer tokenizer.

    This transformer uses the AutoTokenizer tokenizer to convert job
    descriptions into sequences of tokens. These token sequences can
    be used as input to language models.

    Attributes:
        tokenizer_name (str): The name of the tokenizer to use.
                              Defaults to 'avisena/bart-base-job-info-summarizer'.
        tokenizer (AutoTokenizer): The instantiated tokenizer.
                                  Initialized as None and loaded during
                                  the `fit` method.

    Examples:
        >>> tokenizer_transformer = TokenizerTransformer()
        >>> tokenizer_transformer.fit(X_train)
        >>> tokenized_descriptions = tokenizer_transformer.transform(X_test)
    """

    def __init__(self, tokenizer_name="avisena/bart-base-job-info-summarizer"):
        """
        Initializes the TokenizerTransformer.

        Args:
            tokenizer_name (str): The name of the tokenizer to use.
        """
        self.tokenizer_name = tokenizer_name
        self.tokenizer = None

    def fit(self, X, y=None):
        """
        Fits the transformer to the training data.

        This method loads the specified tokenizer.

        Args:
            X (pd.DataFrame): The training data.
                              Must contain a 'Job Description' column.
            y (pd.Series, optional): The labels for the training data.
                                      Not used in this transformer.
                                      Defaults to None.

        Returns:
            self: The fitted TokenizerTransformer object.
        """
        self.tokenizer = AutoTokenizer.from_pretrained(self.tokenizer_name)
        return self

    def transform(self, X):
        """
        Tokenizes the input data using the tokenizer.

        Args:
            X (pd.DataFrame): The data to tokenize.
                              Must contain a 'Job Description' column.

        Returns:
            np.ndarray: The token sequences generated by the tokenizer.
        """
        X = X['Job Description'].astype(str)  # Ensure descriptions are strings
        all_encoded_inputs = []
        for job_description in X.values:
            inputs = self.tokenizer.encode(
                job_description,
                return_tensors="pt",
                max_length=1024,
                truncation=True,
                padding='max_length'
            )
            all_encoded_inputs.append(inputs[0].tolist()) # Get the list of token IDs
        return np.array(all_encoded_inputs)  # Return as NumPy array

# %%
# columns by tipe
categorical_features = ['Size', 'Type of ownership', 'Sector', 'Revenue']
encode_features = ['Job Title']
tokenizer_features = ['Job Description']

##########################################
############ transformers ################
##########################################
# prepocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(sparse_output=False,max_categories=5,
                              handle_unknown='ignore'), categorical_features),
        ('job_titles', EncodeTransformer(), encode_features),
        ('job_descriptions', TokenizerTransformer(), tokenizer_features),
    ])

# etl
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler()) # escalamiento de los datos
    ])

pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('ohe',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 max_categories=5,
#                                                                 sparse_output=False),
#                                                   ['Size', 'Type of ownership',
#                                                    'Sector', 'Revenue']),
#                                                  ('job_titles',
#                                                   EncodeTransformer(),
#                                                   ['Job Title']),
#                                                  ('job_descriptions',
#                                                   TokenizerTransformer(),
#                                                   ['Job Description'])])),
#                 ('scaler', StandardScaler())])

# %% [markdown]
# ## 4.5 Procesamiento

# %%
 # TRAIN: FIT & TRANSFORM
X_train_transfomed = pipeline.fit_transform(X_train)

# TEST: ONLY TRANSFORM
X_test_transfomed = pipeline.transform(X_test)

# %%
print(f'X_train_transformed size: {X_train_transfomed.shape}')
print(f'X_test_transformed size: {X_test_transfomed.shape}')
# Out:
# X_train_transformed size: (183, 1812)
# X_test_transformed size: (79, 1812)

# %% [markdown]
# # 5. Modelado
# Usaremos una red neuronal densa para predecir el salario.

# %%
model_nn = keras.models.Sequential([
  keras.layers.Input((X_train_transfomed.shape[1],), name = 'input'),
  keras.layers.Dense(906,  name='first_layer',  activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  keras.layers.Dense(452,  name='second_layer', activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  keras.layers.Dense(226,  name='third_layer',  activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  keras.layers.Dense(112,  name='fourth_layer', activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  #keras.layers.Dense(56,  name='fifth_layer', activation="relu", kernel_regularizer=regularizers.l2(0.01)),
  #keras.layers.Dense(28,  name='sixth_layer', activation="linear", kernel_regularizer=regularizers.l2(0.01)),
  keras.layers.Dense(1, name='output')
  ]
)

model_nn.compile(
    loss='mse',
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    metrics=['mean_absolute_error']
)


model_nn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 906)               1642578
#
#  second_layer (Dense)        (None, 452)               409964
#
#  third_layer (Dense)         (None, 226)               102378
#
#  fourth_layer (Dense)        (None, 112)               25424
#
#  output (Dense)              (None, 1)                 113
#
# =================================================================
# Total params: 2180457 (8.32 MB)
# Trainable params: 2180457 (8.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# train
history = model_nn.fit(
    X_train_transfomed,
    y_train['salary_max'].astype(float).values,
    epochs=75,
    validation_split=0.3,
)
# Out:
# Epoch 1/75
# 4/4 [==============================] - 0s 144ms/step - loss: 638065280.0000 - mean_absolute_error: 20018.6758 - val_loss: 3246044672.0000 - val_mean_absolute_error: 47759.3164
# Epoch 2/75
# 4/4 [==============================] - 0s 113ms/step - loss: 529158496.0000 - mean_absolute_error: 17992.4688 - val_loss: 3246834944.0000 - val_mean_absolute_error: 47863.8711
# Epoch 3/75
# 4/4 [==============================] - 0s 113ms/step - loss: 411835072.0000 - mean_absolute_error: 15700.9473 - val_loss: 3254124032.0000 - val_mean_absolute_error: 48249.6367
# Epoch 4/75
# 4/4 [==============================] - 0s 105ms/step - loss: 331257888.0000 - mean_absolute_error: 14041.0645 - val_loss: 3221432832.0000 - val_mean_absolute_error: 48019.6641
# Epoch 5/75
# 4/4 [==============================] - 0s 112ms/step - loss: 260347648.0000 - mean_absolute_error: 12327.0195 - val_loss: 3165358592.0000 - val_mean_absolute_error: 47419.5078
# Epoch 6/75
# 4/4 [==============================] - 0s 119ms/step - loss: 195353920.0000 - mean_absolute_error: 10635.1094 - val_loss: 3115843584.0000 - val_mean_absolute_error: 46798.0664
# Epoch 7/75
# 4/4 [==============================] - 0s 112ms/step - loss: 146067776.0000 - mean_absolute_error: 9033.5342 - val_loss: 3074861056.0000 - val_mean_absolute_error: 46480.3711
# Epoch 8/75
# 4/4 [==============================] - 0s 124ms/step - loss: 112433592.0000 - mean_absolute_error: 7890.9619 - val_loss: 3043430144.0000 - val_mean_absolute_error: 46431.1992
# Epoch 9/75
# 4/4 [==============================] - 0s 108ms/step - loss: 85604232.0000 - mean_absolute_error: 7038.9116 - val_loss: 3022503936.0000 - val_mean_absolute_error: 45986.5000
# Epoch 10/75
# 4/4 [==============================] - 0s 105ms/step - loss: 62663540.0000 - mean_absolute_error: 5812.5488 - val_loss: 3011992576.0000 - val_mean_absolute_error: 45706.8711
# Epoch 11/75
# 4/4 [==============================] - 0s 106ms/step - loss: 46833760.0000 - mean_absolute_error: 5112.5991 - val_loss: 2999406848.0000 - val_mean_absolute_error: 45608.6445
# Epoch 12/75
# 4/4 [==============================] - 0s 121ms/step - loss: 34866092.0000 - mean_absolute_error: 4365.7832 - val_loss: 2991525376.0000 - val_mean_absolute_error: 45599.4414
# Epoch 13/75
# 4/4 [==============================] - 0s 97ms/step - loss: 25942362.0000 - mean_absolute_error: 3803.5952 - val_loss: 2987521024.0000 - val_mean_absolute_error: 45514.6406
# Epoch 14/75
# 4/4 [==============================] - 0s 70ms/step - loss: 17696826.0000 - mean_absolute_error: 3111.7017 - val_loss: 2975411968.0000 - val_mean_absolute_error: 45345.6602
# Epoch 15/75
# 4/4 [==============================] - 0s 70ms/step - loss: 14341116.0000 - mean_absolute_error: 2807.3833 - val_loss: 2976539648.0000 - val_mean_absolute_error: 45351.3008
# Epoch 16/75
# 4/4 [==============================] - 0s 88ms/step - loss: 10225119.0000 - mean_absolute_error: 2249.8267 - val_loss: 2986607360.0000 - val_mean_absolute_error: 45473.1094
# Epoch 17/75
# 4/4 [==============================] - 0s 70ms/step - loss: 7674551.0000 - mean_absolute_error: 1997.2393 - val_loss: 2980983808.0000 - val_mean_absolute_error: 45410.3320
# Epoch 18/75
# 4/4 [==============================] - 0s 69ms/step - loss: 5566548.0000 - mean_absolute_error: 1625.1805 - val_loss: 2971659264.0000 - val_mean_absolute_error: 45282.2266
# Epoch 19/75
# 4/4 [==============================] - 0s 50ms/step - loss: 4555699.5000 - mean_absolute_error: 1436.3612 - val_loss: 2968605696.0000 - val_mean_absolute_error: 45239.5664
# Epoch 20/75
# 4/4 [==============================] - 0s 49ms/step - loss: 3453297.0000 - mean_absolute_error: 1193.2957 - val_loss: 2967170816.0000 - val_mean_absolute_error: 45233.7539
# Epoch 21/75
# 4/4 [==============================] - 0s 52ms/step - loss: 2856077.7500 - mean_absolute_error: 1082.5897 - val_loss: 2965384448.0000 - val_mean_absolute_error: 45197.4766
# Epoch 22/75
# 4/4 [==============================] - 0s 49ms/step - loss: 2230248.2500 - mean_absolute_error: 921.1732 - val_loss: 2961939712.0000 - val_mean_absolute_error: 45139.4727
# Epoch 23/75
# 4/4 [==============================] - 0s 50ms/step - loss: 1929198.0000 - mean_absolute_error: 865.7965 - val_loss: 2963298304.0000 - val_mean_absolute_error: 45144.8906
# Epoch 24/75
# 4/4 [==============================] - 0s 48ms/step - loss: 1528334.8750 - mean_absolute_error: 752.3326 - val_loss: 2968023552.0000 - val_mean_absolute_error: 45183.3125
# Epoch 25/75
# 4/4 [==============================] - 0s 51ms/step - loss: 1305411.0000 - mean_absolute_error: 656.5048 - val_loss: 2966705408.0000 - val_mean_absolute_error: 45161.4141
# Epoch 26/75
# 4/4 [==============================] - 0s 47ms/step - loss: 1069447.6250 - mean_absolute_error: 569.1750 - val_loss: 2964490496.0000 - val_mean_absolute_error: 45143.7891
# Epoch 27/75
# 4/4 [==============================] - 0s 49ms/step - loss: 939312.5000 - mean_absolute_error: 497.9037 - val_loss: 2966796544.0000 - val_mean_absolute_error: 45158.6367
# Epoch 28/75
# 4/4 [==============================] - 0s 48ms/step - loss: 833814.3750 - mean_absolute_error: 479.7181 - val_loss: 2966438144.0000 - val_mean_absolute_error: 45159.3320
# Epoch 29/75
# 4/4 [==============================] - 0s 48ms/step - loss: 692046.4375 - mean_absolute_error: 405.7488 - val_loss: 2964114432.0000 - val_mean_absolute_error: 45147.8984
# Epoch 30/75
# 4/4 [==============================] - 0s 49ms/step - loss: 634303.5625 - mean_absolute_error: 369.6117 - val_loss: 2965334784.0000 - val_mean_absolute_error: 45154.5938
# Epoch 31/75
# 4/4 [==============================] - 0s 49ms/step - loss: 550429.5625 - mean_absolute_error: 321.8160 - val_loss: 2966845696.0000 - val_mean_absolute_error: 45162.8828
# Epoch 32/75
# 4/4 [==============================] - 0s 55ms/step - loss: 489561.2500 - mean_absolute_error: 296.1456 - val_loss: 2967276544.0000 - val_mean_absolute_error: 45164.5625
# Epoch 33/75
# 4/4 [==============================] - 0s 50ms/step - loss: 446280.0625 - mean_absolute_error: 274.4304 - val_loss: 2967539968.0000 - val_mean_absolute_error: 45163.4180
# Epoch 34/75
# 4/4 [==============================] - 0s 49ms/step - loss: 410624.8438 - mean_absolute_error: 259.5900 - val_loss: 2966721536.0000 - val_mean_absolute_error: 45154.4805
# Epoch 35/75
# 4/4 [==============================] - 0s 49ms/step - loss: 373638.5625 - mean_absolute_error: 241.4869 - val_loss: 2965620736.0000 - val_mean_absolute_error: 45144.5938
# Epoch 36/75
# 4/4 [==============================] - 0s 49ms/step - loss: 343377.7812 - mean_absolute_error: 220.5718 - val_loss: 2966210560.0000 - val_mean_absolute_error: 45145.5859
# Epoch 37/75
# 4/4 [==============================] - 0s 51ms/step - loss: 319929.0000 - mean_absolute_error: 204.1124 - val_loss: 2965143808.0000 - val_mean_absolute_error: 45136.6172
# Epoch 38/75
# 4/4 [==============================] - 0s 52ms/step - loss: 324551.8125 - mean_absolute_error: 236.4340 - val_loss: 2964867584.0000 - val_mean_absolute_error: 45131.3398
# Epoch 39/75
# 4/4 [==============================] - 0s 49ms/step - loss: 277695.7500 - mean_absolute_error: 198.5496 - val_loss: 2966184704.0000 - val_mean_absolute_error: 45134.3008
# Epoch 40/75
# 4/4 [==============================] - 0s 47ms/step - loss: 263476.1875 - mean_absolute_error: 200.5301 - val_loss: 2964942592.0000 - val_mean_absolute_error: 45125.4219
# Epoch 41/75
# 4/4 [==============================] - 0s 50ms/step - loss: 242473.3594 - mean_absolute_error: 184.1075 - val_loss: 2964339200.0000 - val_mean_absolute_error: 45120.9648
# Epoch 42/75
# 4/4 [==============================] - 0s 60ms/step - loss: 237688.7969 - mean_absolute_error: 170.8741 - val_loss: 2965420032.0000 - val_mean_absolute_error: 45123.1562
# Epoch 43/75
# 4/4 [==============================] - 0s 55ms/step - loss: 221484.9062 - mean_absolute_error: 148.3110 - val_loss: 2965215744.0000 - val_mean_absolute_error: 45117.0547
# Epoch 44/75
# 4/4 [==============================] - 0s 50ms/step - loss: 197886.0938 - mean_absolute_error: 145.7388 - val_loss: 2965194496.0000 - val_mean_absolute_error: 45112.1445
# Epoch 45/75
# 4/4 [==============================] - 0s 47ms/step - loss: 188900.9062 - mean_absolute_error: 137.2301 - val_loss: 2964432896.0000 - val_mean_absolute_error: 45103.7148
# Epoch 46/75
# 4/4 [==============================] - 0s 50ms/step - loss: 188851.6250 - mean_absolute_error: 159.3758 - val_loss: 2964012800.0000 - val_mean_absolute_error: 45095.9648
# Epoch 47/75
# 4/4 [==============================] - 0s 50ms/step - loss: 171821.5156 - mean_absolute_error: 132.9918 - val_loss: 2964861952.0000 - val_mean_absolute_error: 45097.6133
# Epoch 48/75
# 4/4 [==============================] - 0s 52ms/step - loss: 156741.0156 - mean_absolute_error: 126.4964 - val_loss: 2964012800.0000 - val_mean_absolute_error: 45091.2773
# Epoch 49/75
# 4/4 [==============================] - 0s 52ms/step - loss: 167013.6875 - mean_absolute_error: 166.1082 - val_loss: 2963680256.0000 - val_mean_absolute_error: 45086.5508
# Epoch 50/75
# 4/4 [==============================] - 0s 50ms/step - loss: 147359.5469 - mean_absolute_error: 122.4167 - val_loss: 2964946688.0000 - val_mean_absolute_error: 45087.1289
# Epoch 51/75
# 4/4 [==============================] - 0s 51ms/step - loss: 139876.8750 - mean_absolute_error: 125.1522 - val_loss: 2963488000.0000 - val_mean_absolute_error: 45080.0195
# Epoch 52/75
# 4/4 [==============================] - 0s 48ms/step - loss: 129983.8516 - mean_absolute_error: 143.8043 - val_loss: 2962913024.0000 - val_mean_absolute_error: 45074.7773
# Epoch 53/75
# 4/4 [==============================] - 0s 49ms/step - loss: 123151.1250 - mean_absolute_error: 116.9402 - val_loss: 2963743488.0000 - val_mean_absolute_error: 45070.3555
# Epoch 54/75
# 4/4 [==============================] - 0s 54ms/step - loss: 116857.7734 - mean_absolute_error: 108.5984 - val_loss: 2962821888.0000 - val_mean_absolute_error: 45069.6641
# Epoch 55/75
# 4/4 [==============================] - 0s 49ms/step - loss: 116915.2422 - mean_absolute_error: 139.1987 - val_loss: 2962687744.0000 - val_mean_absolute_error: 45065.6914
# Epoch 56/75
# 4/4 [==============================] - 0s 49ms/step - loss: 98558.4297 - mean_absolute_error: 104.2096 - val_loss: 2963668736.0000 - val_mean_absolute_error: 45062.0625
# Epoch 57/75
# 4/4 [==============================] - 0s 52ms/step - loss: 102079.4766 - mean_absolute_error: 118.7939 - val_loss: 2962826752.0000 - val_mean_absolute_error: 45060.4961
# Epoch 58/75
# 4/4 [==============================] - 0s 52ms/step - loss: 92837.0781 - mean_absolute_error: 114.5134 - val_loss: 2962204672.0000 - val_mean_absolute_error: 45057.5781
# Epoch 59/75
# 4/4 [==============================] - 0s 50ms/step - loss: 87651.3672 - mean_absolute_error: 94.9825 - val_loss: 2963130112.0000 - val_mean_absolute_error: 45054.2188
# Epoch 60/75
# 4/4 [==============================] - 0s 52ms/step - loss: 81582.3750 - mean_absolute_error: 82.5290 - val_loss: 2962608384.0000 - val_mean_absolute_error: 45054.0078
# Epoch 61/75
# 4/4 [==============================] - 0s 51ms/step - loss: 74044.9688 - mean_absolute_error: 91.9067 - val_loss: 2962355200.0000 - val_mean_absolute_error: 45051.6172
# Epoch 62/75
# 4/4 [==============================] - 0s 51ms/step - loss: 69953.4531 - mean_absolute_error: 81.5541 - val_loss: 2962560768.0000 - val_mean_absolute_error: 45047.6680
# Epoch 63/75
# 4/4 [==============================] - 0s 53ms/step - loss: 67154.5938 - mean_absolute_error: 79.3309 - val_loss: 2962309376.0000 - val_mean_absolute_error: 45042.9531
# Epoch 64/75
# 4/4 [==============================] - 0s 80ms/step - loss: 61901.7695 - mean_absolute_error: 75.1562 - val_loss: 2961577728.0000 - val_mean_absolute_error: 45041.9609
# Epoch 65/75
# 4/4 [==============================] - 0s 80ms/step - loss: 59747.9648 - mean_absolute_error: 86.5039 - val_loss: 2962221056.0000 - val_mean_absolute_error: 45039.9180
# Epoch 66/75
# 4/4 [==============================] - 0s 77ms/step - loss: 57811.3359 - mean_absolute_error: 75.9528 - val_loss: 2962277632.0000 - val_mean_absolute_error: 45037.6289
# Epoch 67/75
# 4/4 [==============================] - 0s 74ms/step - loss: 51782.9414 - mean_absolute_error: 73.9353 - val_loss: 2961293056.0000 - val_mean_absolute_error: 45035.1562
# Epoch 68/75
# 4/4 [==============================] - 0s 81ms/step - loss: 51092.1914 - mean_absolute_error: 80.7449 - val_loss: 2961669632.0000 - val_mean_absolute_error: 45029.3398
# Epoch 69/75
# 4/4 [==============================] - 0s 70ms/step - loss: 47027.2539 - mean_absolute_error: 67.4996 - val_loss: 2961249024.0000 - val_mean_absolute_error: 45026.9258
# Epoch 70/75
# 4/4 [==============================] - 0s 81ms/step - loss: 48774.4922 - mean_absolute_error: 86.6346 - val_loss: 2960973568.0000 - val_mean_absolute_error: 45024.9727
# Epoch 71/75
# 4/4 [==============================] - 0s 72ms/step - loss: 40498.6484 - mean_absolute_error: 67.6628 - val_loss: 2961500928.0000 - val_mean_absolute_error: 45021.5820
# Epoch 72/75
# 4/4 [==============================] - 0s 84ms/step - loss: 39711.9609 - mean_absolute_error: 67.0728 - val_loss: 2960807936.0000 - val_mean_absolute_error: 45020.1992
# Epoch 73/75
# 4/4 [==============================] - 0s 82ms/step - loss: 36573.8633 - mean_absolute_error: 74.8074 - val_loss: 2960823296.0000 - val_mean_absolute_error: 45019.1914
# Epoch 74/75
# 4/4 [==============================] - 0s 71ms/step - loss: 32959.5469 - mean_absolute_error: 52.9309 - val_loss: 2961337088.0000 - val_mean_absolute_error: 45017.6602
# Epoch 75/75
# 4/4 [==============================] - 0s 83ms/step - loss: 31914.7676 - mean_absolute_error: 55.0183 - val_loss: 2960942080.0000 - val_mean_absolute_error: 45016.0352

# %% [markdown]
# # 6. Evaluación

# %%
# Graficar la función de pérdida
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Entrenamiento', color='turquoise')
plt.title('Función de Pérdida del Modelo')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()
plt.show()

# %%
y_train_pred = model_nn.predict(X_train_transfomed)
y_test_pred = model_nn.predict(X_test_transfomed)
# Out:
# 6/6 [==============================] - 0s 9ms/step
# 3/3 [==============================] - 0s 9ms/step

# %%
# metrics
rmse = mean_squared_error(y_train['salary_max'].astype(float).values, y_train_pred)**0.5
mae = mean_absolute_error(y_train['salary_max'].astype(float).values, y_train_pred)
r2 = r2_score( y_train['salary_max'].astype(float).values, y_train_pred)

print('Train Metrics:')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R^2: {r2:.4f}')

print('-'*20)

rmse = mean_squared_error( y_test['salary_max'].astype(float).values, y_test_pred)**0.5
mae = mean_absolute_error( y_test['salary_max'].astype(float).values, y_test_pred)
r2 = r2_score( y_test['salary_max'].astype(float).values, y_test_pred)

print('Test Metrics:')
print(f'RMSE: {rmse:.4f}')
print(f'MAE: {mae:.4f}')
print(f'R^2: {r2:.4f}')
# Out:
# Train Metrics:
# RMSE: 29831.5415
# MAE: 13564.4761
# R^2: -3.2130
# --------------------
# Test Metrics:
# RMSE: 44874.7481
# MAE: 36389.0075
# R^2: -10.1706
